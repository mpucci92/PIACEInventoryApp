# %%
import pandas as pd
import numpy as np

# %%
path_to_data = r"Test2 - PI ACE Migration_FULL.csv"
df = pd.read_csv(path_to_data)
df
# Out:
#                                                   Name      Type  \
# 0                                      \\SVCS-ACE\%OSI    Module
# 1                      \\SVCS-ACE\%OSI\ACE2xSchedulers    Module
# 2           \\SVCS-ACE\%OSI\ACE2xSchedulers||IsDefault  Property
# 3    \\SVCS-ACE\%OSI\ACE2xSchedulers||LastDisplayed...  Property
# 4              \\SVCS-ACE\%OSI\ACE2xSchedulers\default    Module
# ..                                                 ...       ...
# 398         \\SVCS-ACE\%OSI\MDB-AFMigrationData||AFCST  Property
# 399         \\SVCS-ACE\%OSI\MDB-AFMigrationData||BRChk  Property
# 400                             \\SVCS-ACE\%OSI\Server    Module
# 401                              \\SVCS-ACE\Compressor    Module
# 402                     \\SVCS-ACE\Compressor|Pressure     Alias
#
#         ModuleCreationDate ModuleCreator  \
# 0     2/28/2022 9:49:32 AM       piadmin
# 1    2/28/2022 10:56:44 AM       piadmin
# 2                      NaN           NaN
# 3                      NaN           NaN
# 4    2/28/2022 10:56:44 AM       piadmin
# ..                     ...           ...
# 398                    NaN           NaN
# 399                    NaN           NaN
# 400   2/28/2022 9:49:32 AM       piadmin
# 401   3/2/2022 11:26:52 AM       piadmin
# 402                    NaN           NaN
#
#                         ModuleDescription    ModuleEffectiveDate  \
# 0    OSI Internal Application Information  12/31/1969 7:00:01 PM
# 1                                     NaN  12/31/1969 7:00:01 PM
# 2                                     NaN                    NaN
# 3                                     NaN                    NaN
# 4                                     NaN  12/31/1969 7:00:01 PM
# ..                                    ...                    ...
# 398                                   NaN                    NaN
# 399                                   NaN                    NaN
# 400       OSI Internal Server Information  12/31/1969 7:00:01 PM
# 401                                   NaN  12/31/1969 7:00:01 PM
# 402                                   NaN                    NaN
#
#     ModuleIsPIUnit ModuleModifier       ModuleModifyDate  ModuleObsoleteDate  \
# 0            False        piadmin   2/28/2022 9:49:32 AM                 NaN
# 1            False        piadmin  2/28/2022 10:56:51 AM                 NaN
# 2              NaN            NaN                    NaN                 NaN
# 3              NaN            NaN                    NaN                 NaN
# 4            False        piadmin   5/30/2022 3:55:34 PM                 NaN
# ..             ...            ...                    ...                 ...
# 398            NaN            NaN                    NaN                 NaN
# 399            NaN            NaN                    NaN                 NaN
# 400          False        piadmin   2/28/2022 9:49:32 AM                 NaN
# 401          False        piadmin   3/2/2022 11:27:19 AM                 NaN
# 402            NaN            NaN                    NaN                 NaN
#
#      ModuleParentCount  ModulePIHeading  ModuleRevisionNumber ModuleSecurity  \
# 0                  1.0              NaN                   1.0   piadmin: A(r
# 1                  1.0              NaN                   3.0   piadmin: A(r
# 2                  NaN              NaN                   NaN            NaN
# 3                  NaN              NaN                   NaN            NaN
# 4                  1.0              NaN                  11.0   piadmin: A(r
# ..                 ...              ...                   ...            ...
# 398                NaN              NaN                   NaN            NaN
# 399                NaN              NaN                   NaN            NaN
# 400                1.0              NaN                   1.0   piadmin: A(r
# 401                1.0              NaN                   3.0   piadmin: A(r
# 402                NaN              NaN                   NaN            NaN
#
#          ModuleUniqueID ModuleVersionComment  \
# 0    w) | piadmins: A(r   w) | PIWorld: A(r)
# 1    w) | piadmins: A(r   w) | PIWorld: A(r)
# 2                   NaN                  NaN
# 3                   NaN                  NaN
# 4    w) | piadmins: A(r   w) | PIWorld: A(r)
# ..                  ...                  ...
# 398                 NaN                  NaN
# 399                 NaN                  NaN
# 400  w) | piadmins: A(r   w) | PIWorld: A(r)
# 401  w) | piadmins: A(r   w) | PIWorld: A(r)
# 402                 NaN                  NaN
#
#                           AliasDataSource PropertyType PropertyValue
# 0    5c64c379-c182-4f35-8d30-78d8c2f84501          NaN           NaN
# 1    8e314865-96e9-426a-8bba-c6eae2846419          NaN           NaN
# 2                                     NaN      Integer             1
# 3                                     NaN       String     SVCS-ACE|
# 4    a12a6aba-bd5d-4fc9-98bd-5f7d69d5913e          NaN           NaN
# ..                                    ...          ...           ...
# 398                                   NaN       Double    1646238466
# 399                                   NaN       Double    1646238466
# 400  dd26b49e-6551-422f-8aed-03bff6e2756b          NaN           NaN
# 401  b974e26a-f754-4850-8d5a-4de421a1b9ec          NaN           NaN
# 402                 \\SVCS-ACE\BrianFLoat          NaN           NaN
#
# [403 rows x 19 columns]

# %%
df = df[df['Name'].str.contains("ACEClassLibraries")].reset_index(drop=True)
df
# Out:
#                                                   Name      Type  \
# 0                    \\SVCS-ACE\%OSI\ACEClassLibraries    Module
# 1         \\SVCS-ACE\%OSI\ACEClassLibraries||IsDefault  Property
# 2          \\SVCS-ACE\%OSI\ACEClassLibraries||IsLocked  Property
# 3        \\SVCS-ACE\%OSI\ACEClassLibraries||IsModified  Property
# 4      \\SVCS-ACE\%OSI\ACEClassLibraries||MessageLevel  Property
# ..                                                 ...       ...
# 139  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 140  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 141  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 142  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 143  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
#
#         ModuleCreationDate ModuleCreator ModuleDescription  \
# 0    2/28/2022 10:56:44 AM       piadmin               NaN
# 1                      NaN           NaN               NaN
# 2                      NaN           NaN               NaN
# 3                      NaN           NaN               NaN
# 4                      NaN           NaN               NaN
# ..                     ...           ...               ...
# 139                    NaN           NaN               NaN
# 140                    NaN           NaN               NaN
# 141                    NaN           NaN               NaN
# 142                    NaN           NaN               NaN
# 143                    NaN           NaN               NaN
#
#        ModuleEffectiveDate ModuleIsPIUnit ModuleModifier  \
# 0    12/31/1969 7:00:01 PM          False        piadmin
# 1                      NaN            NaN            NaN
# 2                      NaN            NaN            NaN
# 3                      NaN            NaN            NaN
# 4                      NaN            NaN            NaN
# ..                     ...            ...            ...
# 139                    NaN            NaN            NaN
# 140                    NaN            NaN            NaN
# 141                    NaN            NaN            NaN
# 142                    NaN            NaN            NaN
# 143                    NaN            NaN            NaN
#
#          ModuleModifyDate  ModuleObsoleteDate  ModuleParentCount  \
# 0    5/30/2022 3:55:33 PM                 NaN                1.0
# 1                     NaN                 NaN                NaN
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# ..                    ...                 ...                ...
# 139                   NaN                 NaN                NaN
# 140                   NaN                 NaN                NaN
# 141                   NaN                 NaN                NaN
# 142                   NaN                 NaN                NaN
# 143                   NaN                 NaN                NaN
#
#      ModulePIHeading  ModuleRevisionNumber ModuleSecurity      ModuleUniqueID  \
# 0                NaN                   6.0   piadmin: A(r  w) | piadmins: A(r
# 1                NaN                   NaN            NaN                 NaN
# 2                NaN                   NaN            NaN                 NaN
# 3                NaN                   NaN            NaN                 NaN
# 4                NaN                   NaN            NaN                 NaN
# ..               ...                   ...            ...                 ...
# 139              NaN                   NaN            NaN                 NaN
# 140              NaN                   NaN            NaN                 NaN
# 141              NaN                   NaN            NaN                 NaN
# 142              NaN                   NaN            NaN                 NaN
# 143              NaN                   NaN            NaN                 NaN
#
#     ModuleVersionComment                       AliasDataSource PropertyType  \
# 0     w) | PIWorld: A(r)  ad3c4f8c-8ad1-4c91-8f50-f52be7322710          NaN
# 1                    NaN                                   NaN      Integer
# 2                    NaN                                   NaN         Long
# 3                    NaN                                   NaN         Long
# 4                    NaN                                   NaN       Double
# ..                   ...                                   ...          ...
# 139                  NaN                                   NaN         Long
# 140                  NaN                                   NaN       PITime
# 141                  NaN                                   NaN         Long
# 142                  NaN                                   NaN         Long
# 143                  NaN                                   NaN       Double
#
#             PropertyValue
# 0                     NaN
# 1                       1
# 2                       0
# 3                       0
# 4              1073739775
# ..                    ...
# 139                     1
# 140  5/30/2022 3:55:35 PM
# 141                     0
# 142                     0
# 143                   600
#
# [144 rows x 19 columns]

# %% [markdown]
# # Module Extraction #

# %%
module_df = df[df['Type'] == "Module"]
module_df = module_df.reset_index(drop=True)

moduleNameList = []
for i in range(len(module_df['Name'])):
    module_df['Name'].apply(lambda x: x.split("\\"))[i]
    filterIndex = module_df['Name'].apply(lambda x: x.split("\\"))[i].index("ACEClassLibraries")
    module_df['Name'].apply(lambda x: x.split("\\"))[i][filterIndex:]
    "\\".join(module_df['Name'].apply(lambda x: x.split("\\"))[i][filterIndex:])
    moduleName = "\\".join(module_df['Name'].apply(lambda x: x.split("\\"))[i][filterIndex:])
    moduleNameList.append(moduleName)

moduleNameList
# Out:
# ['ACEClassLibraries',
#  'ACEClassLibraries\\BrianFirstACE',
#  'ACEClassLibraries\\BrianFirstACE\\Main',
#  'ACEClassLibraries\\BrianFirstACE\\Main\\Context1',
#  'ACEClassLibraries\\MichaelFirstACE',
#  'ACEClassLibraries\\MichaelFirstACE\\Main',
#  'ACEClassLibraries\\MichaelFirstACE\\Main\\Context1']

# %%
module_df['ModuleName'] = moduleNameList
module_df = module_df.loc[:,['Name','Type','ModuleName','ModuleCreator']]
module_df.columns = ['FullPath','Type','ModuleName','ModuleCreator']
module_df
# Out:
#                                             FullPath    Type  \
# 0                  \\SVCS-ACE\%OSI\ACEClassLibraries  Module
# 1    \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstACE  Module
# 2  \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstAC...  Module
# 3  \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstAC...  Module
# 4  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirstACE  Module
# 5  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Module
# 6  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Module
#
#                                         ModuleName ModuleCreator
# 0                                ACEClassLibraries       piadmin
# 1                  ACEClassLibraries\BrianFirstACE       piadmin
# 2             ACEClassLibraries\BrianFirstACE\Main       piadmin
# 3    ACEClassLibraries\BrianFirstACE\Main\Context1       piadmin
# 4                ACEClassLibraries\MichaelFirstACE    OSI\mpucci
# 5           ACEClassLibraries\MichaelFirstACE\Main    OSI\mpucci
# 6  ACEClassLibraries\MichaelFirstACE\Main\Context1    OSI\mpucci

# %% [markdown]
# # Property Extraction #

# %%
df.rename(columns = {'Name':'FullPath'}, inplace = True)

ModuleIndexes = []

for i in range(len(module_df)):
    ModuleIndexes.append(list(df['FullPath']).index(module_df['FullPath'][i]))

DataframeList = []

for i in range(len(ModuleIndexes)):
    propertyList = []
    try:
        tmp = df.loc[ModuleIndexes[i]:ModuleIndexes[i+1]-1,:]

        tmp = tmp.loc[:,['FullPath','Type','PropertyValue']]
        
        for j in range(len(tmp)):
            try:
                propertyList.append(list(tmp['FullPath'].apply(lambda x: x.split("||")))[j][1])
            except Exception as e:
                propertyList.append(None)
                continue
            
        tmp['PropertyName'] = propertyList
        final = tmp.loc[:,['FullPath','Type','PropertyName','PropertyValue']]
        DataframeList.append(final)
    except Exception as e:
        tmp = df.loc[ModuleIndexes[i]:,:]
        tmp = tmp.loc[:,['FullPath','Type','PropertyValue']]
        
        for j in range(len(tmp)):
            try:
                propertyList.append(list(tmp['FullPath'].apply(lambda x: x.split("||")))[j][1])
            except Exception as e:
                propertyList.append(None)
                continue
            
        tmp['PropertyName'] = propertyList
        final = tmp.loc[:,['FullPath','Type','PropertyName','PropertyValue']]
        DataframeList.append(final)

# %%
# Out:
#                                           FullPath      Type  PropertyName  \
# 0                \\SVCS-ACE\%OSI\ACEClassLibraries    Module          None
# 1     \\SVCS-ACE\%OSI\ACEClassLibraries||IsDefault  Property     IsDefault
# 2      \\SVCS-ACE\%OSI\ACEClassLibraries||IsLocked  Property      IsLocked
# 3    \\SVCS-ACE\%OSI\ACEClassLibraries||IsModified  Property    IsModified
# 4  \\SVCS-ACE\%OSI\ACEClassLibraries||MessageLevel  Property  MessageLevel
# 5          \\SVCS-ACE\%OSI\ACEClassLibraries||Port  Property          Port
# 6     \\SVCS-ACE\%OSI\ACEClassLibraries||Scheduler  Property     Scheduler
# 7        \\SVCS-ACE\%OSI\ACEClassLibraries||Status  Property        Status
# 8   \\SVCS-ACE\%OSI\ACEClassLibraries||StatusSince  Property   StatusSince
# 9          \\SVCS-ACE\%OSI\ACEClassLibraries||User  Property          User
#
#            PropertyValue
# 0                    NaN
# 1                      1
# 2                      0
# 3                      0
# 4             1073739775
# 5                   5456
# 6               SVCS-ACE
# 7                      1
# 8  2/28/2022 10:56:44 AM
# 9                    NaN

# %%
ModuleDictionary = {}

for i, name in enumerate(module_df['ModuleName']):
    ModuleDictionary[i] = name

for i in range(len(DataframeList)):
    csvName = ModuleDictionary[i].replace("\\","-")
    DataframeList[i].to_csv(f"E:\\OSI Backup\\Systems Engineer\\PI ACE Inventory App\\Output\\{csvName}.csv",index=False)

# %%
import pandas as pd
import numpy as np
import glob as glob

folder_path = "D:\Aveva\Output\*.csv"

for i,file in enumerate(glob.glob(folder_path)):
    if  i == 0:
        comp_df = pd.read_csv(file)
        col_comp_names = ['FullPath'] + list(comp_df[comp_df['Type'] == 'Property']['PropertyName'])
        tmp_df = pd.DataFrame(columns=col_comp_names)
        col_values = list(comp_df[comp_df['Type'] == 'Module']['FullPath']) + list(comp_df[comp_df['Type'] == 'Property']['PropertyValue'])
        tmp_df.loc[0] = col_values
    
    else:
        comp_df = pd.read_csv(file)
        col_comp_names = ['FullPath'] + list(comp_df[comp_df['Type'] == 'Property']['PropertyName'])
        tmp_df1 = pd.DataFrame(columns=col_comp_names)
        col_values = list(comp_df[comp_df['Type'] == 'Module']['FullPath']) + list(comp_df[comp_df['Type'] == 'Property']['PropertyValue'])
        tmp_df1.loc[0] = col_values
        tmp_df = pd.concat([tmp_df, tmp_df1], ignore_index=True)
        
tmp_df.to_csv(f"E:\\OSI Backup\\Systems Engineer\\PI ACE Inventory App\\Output\\COMPLETE_V2.csv",index=False)

# %%
# df_empty = pd.DataFrame()
# for i,value in enumerate(DataframeList):
#     if i == 0:
#         complete_df = pd.concat([df_empty, value], axis=0)
#     else:
#         complete_df = pd.concat([complete_df,value],axis = 0)
        
# complete_df.to_csv(f"E:\\OSI Backup\\Systems Engineer\\PI ACE Inventory App\\Output\\COMPLETE.csv",index=False)

# %% [markdown]
# # DONE #

# %%
comp_df = pd.read_csv("D:\Aveva\Output\COMPLETE.csv")

# %%
comp_df
# Out:
#                                               FullPath      Type  \
# 0                    \\SVCS-ACE\%OSI\ACEClassLibraries    Module
# 1         \\SVCS-ACE\%OSI\ACEClassLibraries||IsDefault  Property
# 2          \\SVCS-ACE\%OSI\ACEClassLibraries||IsLocked  Property
# 3        \\SVCS-ACE\%OSI\ACEClassLibraries||IsModified  Property
# 4      \\SVCS-ACE\%OSI\ACEClassLibraries||MessageLevel  Property
# ..                                                 ...       ...
# 139  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 140  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 141  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 142  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
# 143  \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...  Property
#
#             PropertyName         PropertyValue
# 0                    NaN                   NaN
# 1              IsDefault                     1
# 2               IsLocked                     0
# 3             IsModified                     0
# 4           MessageLevel            1073739775
# ..                   ...                   ...
# 139               Status                     1
# 140          StatusSince  5/30/2022 3:55:35 PM
# 141         ScheduleInfo                     0
# 142  ScheduleInfo|Offset                     0
# 143  ScheduleInfo|Period                   600
#
# [144 rows x 4 columns]

# %%
set(comp_df['PropertyName'])
# Out:
# {'AssemblyPath',
#  'AutoRecalculationInfo',
#  'CLViolationCount',
#  'CLViolationCountLimit',
#  'CalculationLimit',
#  'Comment',
#  'ErrorMessage',
#  'FileName',
#  'IsACEExe',
#  'IsDefault',
#  'IsEditing',
#  'IsLocked',
#  'IsModified',
#  'MessageLevel',
#  'Name',
#  'Port',
#  'Priority',
#  'ProcessID',
#  'RevHistory',
#  'ScheduleInfo',
#  'ScheduleInfo|Offset',
#  'ScheduleInfo|Period',
#  'Scheduler',
#  'SourceFileLocation',
#  'Status',
#  'StatusSince',
#  'TagAliases',
#  'TagAliases|Compressor\\Pressure',
#  'TagAliases|Compressor\\Pressure|InputBadValSub',
#  'TagAliases|Compressor\\Pressure|InputClamping',
#  'TagAliases|Compressor\\Pressure|OutputBadValSub',
#  'TagAliases|Compressor\\Pressure|OutputClamping',
#  'TagAliases|Compressor\\Pressure|RevHistory',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|Date',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|InputBadValSub',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|InputClamping',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|Name',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|OutputBadValSub',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|OutputClamping',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|Type',
#  'TagAliases|Compressor\\Pressure|RevHistory|Rev1|User',
#  'TagAliases|Compressor\\Pressure|SourceCodeName',
#  'TagAliases|Test',
#  'TagAliases|Test|InputBadValSub',
#  'TagAliases|Test|InputClamping',
#  'TagAliases|Test|OutputBadValSub',
#  'TagAliases|Test|OutputClamping',
#  'TagAliases|Test|RevHistory',
#  'TagAliases|Test|RevHistory|Rev1',
#  'TagAliases|Test|RevHistory|Rev1|Date',
#  'TagAliases|Test|RevHistory|Rev1|InputBadValSub',
#  'TagAliases|Test|RevHistory|Rev1|InputClamping',
#  'TagAliases|Test|RevHistory|Rev1|Name',
#  'TagAliases|Test|RevHistory|Rev1|OutputBadValSub',
#  'TagAliases|Test|RevHistory|Rev1|OutputClamping',
#  'TagAliases|Test|RevHistory|Rev1|Type',
#  'TagAliases|Test|RevHistory|Rev1|User',
#  'TagAliases|Test|SourceCodeName',
#  'TagAliases|\\InputCount',
#  'TagAliases|\\OutputCount',
#  'User',
#  nan}

# %% [markdown]
# ###### tmpcomp = comp_df.iloc[0:10]
# tmpcomp

# %%
col_comp_names = ['FullPath'] + list(tmpcomp[tmpcomp['Type'] == 'Property']['PropertyName'])
col_values = list(tmpcomp[tmpcomp['Type'] == 'Property']['PropertyValue'])

col_values
# Out:
# ['1',
#  '0',
#  '0',
#  '1073739775',
#  '5456',
#  'SVCS-ACE',
#  '1',
#  '2/28/2022 10:56:44 AM',
#  nan]

# %%
comp_df.iloc[ModuleIndexes]['FullPath']
# Out:
# 0                      \\SVCS-ACE\%OSI\ACEClassLibraries
# 10       \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstACE
# 19     \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstAC...
# 61     \\SVCS-ACE\%OSI\ACEClassLibraries\BrianFirstAC...
# 77     \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirstACE
# 86     \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...
# 128    \\SVCS-ACE\%OSI\ACEClassLibraries\MichaelFirst...
# Name: FullPath, dtype: object

# %%
cc_df = pd.DataFrame(columns = col_comp_names)

# %%
cc_df
# Out:
# Empty DataFrame
# Columns: [FullPath, IsDefault, IsLocked, IsModified, MessageLevel, Port, Scheduler, Status, StatusSince, User]
# Index: []
